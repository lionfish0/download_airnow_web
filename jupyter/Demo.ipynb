# %%
from download_airnow_web import download
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = download('Kampala')

# %%
df = df[df['Raw Conc.']>=0]
plt.scatter(df['Hour'],df['Raw Conc.'],170,marker='s',color='k',alpha=0.002)
plt.ylim([0,160])
# Out:
# (0, 160)
